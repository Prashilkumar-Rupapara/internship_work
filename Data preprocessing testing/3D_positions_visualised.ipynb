# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set display options
pd.set_option('display.width', None)  # Use None to try to display everything on one line
pd.set_option('display.max_colwidth', None)  # Ensure full width of columns if possible

# %%
# Path to the folder
folder_paths = [r'.\..\OneDrive_2025-03-03\LED_data_for prediction\Dataset\Data_preprocessing_2D_CNN\Data_All\Data\SAC105',
	r'.\..\OneDrive_2025-03-03\LED_data_for prediction\Dataset\Data_preprocessing_2D_CNN\Data_All\Data\SAC305',
	r'.\..\OneDrive_2025-03-03\LED_data_for prediction\Dataset\Data_preprocessing_2D_CNN\Data_All\Data\Senju',
]

# %% [markdown]
# # 2D Visualisation

# %%
for folder_path in folder_paths:
	print()
	print()
	print('**', folder_path.split('\\')[-1], '**')
	print()
	print()

	# Get a list of all .npy files in the folder
	npy_files = [os.path.join(folder_path, file) for file in os.listdir(folder_path) if file.endswith('.npy')]

	for npy_file in npy_files:
		arr = np.load(npy_file)
		df = pd.DataFrame(arr, columns=['X Location (µm)', 'Y Location (µm)', 'Z Location (µm)', 'NLCREQ (µm/µm)'])

		# print the file name
		print(npy_file.split('\\')[-1])

		# Calculate the length in each direction
		print()
		print("X Length(µm):", df['X Location (µm)'].max() - df['X Location (µm)'].min())
		print("Y Length(µm):", df['Y Location (µm)'].max() - df['Y Location (µm)'].min())
		print("Z Length(µm):", df['Z Location (µm)'].max() - df['Z Location (µm)'].min())
		print("NLCREQ Length(µm/µm):", df['NLCREQ (µm/µm)'].max() - df['NLCREQ (µm/µm)'].min())

		# Plot X and Y
		plt.figure(figsize=(8, 6))
		plt.plot(df['X Location (µm)'], df['Y Location (µm)'], 'bo', markersize=3)
		plt.xlabel('X Location (µm)')
		plt.ylabel('Y Location (µm)')
		plt.title(npy_file.split('\\')[-1].split('_')[0])
		plt.grid(True)
		plt.gca().set_aspect('equal', adjustable='box')
		# plt.show()

		print('###########################################################')
# Out:
# ** SAC105 **
#
#
# FCGB1_sac105.npy
#
# X Length(µm): 1650.0
# Y Length(µm): 2050.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.503507
# ###########################################################
# FCGB2_sac105.npy
#
# X Length(µm): 1230.0
# Y Length(µm): 1600.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.13219999940573002
# ###########################################################
# FCGB3_sac105.npy
#
# X Length(µm): 1230.0
# Y Length(µm): 1600.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.335152
# ###########################################################
# FCSP2_sac105.npy
#
# X Length(µm): 1500.0
# Y Length(µm): 1500.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.4056157
# ###########################################################
# FCSP3_sac105.npy
#
# X Length(µm): 1700.0
# Y Length(µm): 2250.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.5527006999999999
# ###########################################################
# FCSP4_sac105.npy
#
# X Length(µm): 1410.0
# Y Length(µm): 1680.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.41472772
# ###########################################################
# VTF2_sac105.npy
#
# X Length(µm): 1340.0
# Y Length(µm): 1730.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.40806159999999997
# ###########################################################
#
#
# ** SAC305 **
#
#
# FCGB1_sac305.npy
#
# X Length(µm): 1650.0
# Y Length(µm): 2050.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.5155018
# ###########################################################
# FCGB2_sac305.npy
#
# X Length(µm): 1230.0
# Y Length(µm): 1600.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.14956999572600002
# ###########################################################
# FCGB3_sac305.npy
#
# X Length(µm): 1230.0
# Y Length(µm): 1600.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.3361539
# ###########################################################
# FCSP2_sac305.npy
#
# X Length(µm): 1500.0
# Y Length(µm): 1500.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.4145403
# ###########################################################
# FCSP3_sac305.npy
#
# X Length(µm): 1700.0
# Y Length(µm): 2250.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.5521748000000001
# ###########################################################
# FCSP4_sac305.npy
#
# X Length(µm): 1410.0
# Y Length(µm): 1680.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.42204807
# ###########################################################
# VTF2_sac305.npy
#
# X Length(µm): 1340.0
# Y Length(µm): 1730.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.41827169999999997
# ###########################################################
#
#
# ** Senju **
#
#
# FCGB1_senju.npy
#
# X Length(µm): 1650.0
# Y Length(µm): 2050.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.5342638
# ###########################################################
# FCGB2_senju.npy
#
# X Length(µm): 1230.0
# Y Length(µm): 1600.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.134889982884
# ###########################################################
# FCGB3_senju.npy
#
# X Length(µm): 1230.0
# Y Length(µm): 1600.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.33739359999999996
# ###########################################################
# FCSP2_senju.npy
#
# X Length(µm): 1500.0
# Y Length(µm): 1500.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.43470909999999996
# ###########################################################
# FCSP3_senju.npy
#
# X Length(µm): 1700.0
# Y Length(µm): 2250.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.6030869999999999
# ###########################################################
# FCSP4_senju.npy
#
# X Length(µm): 1410.0
# Y Length(µm): 1680.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.426581
# ###########################################################
# VTF2_senju.npy
#
# X Length(µm): 1340.0
# Y Length(µm): 1730.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.43267545
# ###########################################################
# C:\Users\rupap\AppData\Local\Temp\ipykernel_10744\3007294868.py:26: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(8, 6))

# %% [markdown]
# # 3D Visualization

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px


npy_file = r'.\..\OneDrive_2025-03-03\LED_data_for prediction\Dataset\Data_preprocessing_2D_CNN\Data_All\Data\SAC105\FCGB1_sac105.npy'

arr = np.load(npy_file)
df = pd.DataFrame(arr, columns=['X Location (µm)', 'Y Location (µm)', 'Z Location (µm)', 'NLCREQ (µm/µm)'])

# Calculate the length in each direction
print()
print("X Length(µm):", df['X Location (µm)'].max() - df['X Location (µm)'].min())
print("Y Length(µm):", df['Y Location (µm)'].max() - df['Y Location (µm)'].min())
print("Z Length(µm):", df['Z Location (µm)'].max() - df['Z Location (µm)'].min())
print("NLCREQ Length(µm/µm):", df['NLCREQ (µm/µm)'].max() - df['NLCREQ (µm/µm)'].min())

# Create 3D scatter plot
fig = px.scatter_3d(df, x='X Location (µm)', y='Y Location (µm)', z='Z Location (µm)', 
                    title='3D Scatter Plot of Data Points', 
                    labels={'X Location (µm)': 'X (µm)', 'Y Location (µm)': 'Y (µm)', 'Z Location (µm)': 'Z (µm)'})

# Show the plot
fig.show()
# Out:
# X Length(µm): 1650.0
# Y Length(µm): 2050.0
# Z Length(µm): 75.0
# NLCREQ Length(µm/µm): 0.503507
